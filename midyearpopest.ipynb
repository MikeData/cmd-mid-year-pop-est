# %%
import pandas as pd

source = pd.read_csv("Mid-year estimates 2012 to 2017 for the UK - backseries from SAS.csv")

source[:4]
# Out:
#     LAD_code age  Sex  mid_2017  mid_2016  mid_2015  mid_2014  mid_2013  \
# 0  E06000001   0    0      1016      1087      1014      1065      1085
# 1  E06000001   1    0      1096      1034      1068      1074      1158
# 2  E06000001   2    0      1060      1085      1092      1154      1195
# 3  E06000001   3    0      1108      1110      1149      1206      1170
#
#    mid_2012
# 0      1152
# 1      1174
# 2      1161
# 3      1143

# %%
# Get geography lookup
import requests

url = "https://api.beta.ons.gov.uk/v1/code-lists/mid-year-pop-geography/editions/one-off/codes"

r = requests.get(url)
if r.status_code != 200:
    raise ValueError("Oops")

giantGeoDict = r.json()

geoLookup = {}
for item in giantGeoDict["items"]:
    geoLookup.update({item["id"]:item["label"]})

geoLookup
# Out:
# {'E13000002': 'Outer London',
#  'E13000001': 'Inner London',
#  'N09000010': 'Newry, Mourne and Down',
#  'N09000004': 'Causeway Coast and Glens',
#  'N09000011': 'Ards and North Down',
#  'N09000008': 'Mid and East Antrim',
#  'N09000006': 'Fermanagh and Omagh',
#  'N09000009': 'Mid Ulster',
#  'N09000007': 'Lisburn and Castlereagh',
#  'N09000005': 'Derry City and Strabane',
#  'N09000002': 'Armagh City, Banbridge and Craigavon',
#  'S12000039': 'West Dunbartonshire',
#  'N09000003': 'Belfast',
#  'N92000002': 'Northern Ireland',
#  'S12000026': 'Scottish Borders',
#  'N09000001': 'Antrim and Newtownabbey',
#  'S12000040': 'West Lothian',
#  'S12000030': 'Stirling',
#  'S12000029': 'South Lanarkshire',
#  'S12000027': 'Shetland Islands',
#  'S12000028': 'South Ayrshire',
#  'S12000038': 'Renfrewshire',
#  'S12000021': 'North Ayrshire',
#  'S12000024': 'Perth and Kinross',
#  'S12000023': 'Orkney Islands',
#  'S12000018': 'Inverclyde',
#  'S12000013': 'Eilean Siar',
# ...

# %%
def lookupGeo(cell):
    return geoLookup[cell]

def lookupSex(cell):
    
    sexLookup = {
        2:"Female",
        1:"Male",
        0:"All"
    }
    return sexLookup[cell]

dataFrameList = []

for i in range(3, len(source.columns.values)):
    
    time = source.columns.values[i]
    
    df = pd.DataFrame()
    
    df["V4_0"] = source[time]
    
    df["mid-year-time"] = time
    df["time"] = time
    
    df["geography_codelist"] = source["LAD_code"]
    df["geography"] = source["LAD_code"].apply(lookupGeo)
    
    df["age_codelist"] = source["age"]
    df["age"] = source["age"]
    
    df["mid-year-pop-sex"] = source["Sex"]
    df["sex"] = source["Sex"].apply(lookupSex)
    
    dataFrameList.append(df)
    
finalDf = pd.concat(dataFrameList)

finalDf.to_csv("temp.csv", index=False)

# %%
finalDf
# Out:
#            V4_0 mid-year-time      time geography_codelist   geography  \
# 0          1016      mid_2017  mid_2017          E06000001  Hartlepool
# 1          1096      mid_2017  mid_2017          E06000001  Hartlepool
# 2          1060      mid_2017  mid_2017          E06000001  Hartlepool
# 3          1108      mid_2017  mid_2017          E06000001  Hartlepool
# 4          1123      mid_2017  mid_2017          E06000001  Hartlepool
# 5          1185      mid_2017  mid_2017          E06000001  Hartlepool
# 6          1214      mid_2017  mid_2017          E06000001  Hartlepool
# 7          1193      mid_2017  mid_2017          E06000001  Hartlepool
# 8          1165      mid_2017  mid_2017          E06000001  Hartlepool
# 9          1179      mid_2017  mid_2017          E06000001  Hartlepool
# 10         1171      mid_2017  mid_2017          E06000001  Hartlepool
# 11         1148      mid_2017  mid_2017          E06000001  Hartlepool
# ...
